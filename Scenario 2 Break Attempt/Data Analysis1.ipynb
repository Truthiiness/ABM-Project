# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('traits.csv')
df.describe()
# Out:
#                Step       AgentID  Spear Phishing      Zero Day  \
# count  2.211900e+06  2.211900e+06    2.211900e+06  2.211900e+06
# mean   1.825500e+03  3.035000e+02    1.025359e+02  4.993009e+01
# std    1.053664e+03  1.749369e+02    2.889085e+01  2.842835e+01
# min    1.000000e+00  1.000000e+00    4.001300e+01  0.000000e+00
# 25%    9.130000e+02  1.520000e+02    7.775700e+01  2.537500e+01
# 50%    1.825500e+03  3.035000e+02    1.029070e+02  4.991000e+01
# 75%    2.738000e+03  4.550000e+02    1.276270e+02  7.437500e+01
# max    3.650000e+03  6.060000e+02    1.511250e+02  1.474500e+02
#
#        Tool Sophistication  Attribution Obfuscation       Stealth  \
# count         2.211900e+06             2.211900e+06  2.211900e+06
# mean          8.723119e+01             9.080813e+01  9.184537e+01
# std           2.773672e+01             3.094800e+01  3.116633e+01
# min           3.001300e+01             1.501300e+01  1.501300e+01
# 25%           6.382600e+01             6.719600e+01  6.796200e+01
# 50%           8.756550e+01             9.230300e+01  9.318300e+01
# 75%           1.111200e+02             1.171040e+02  1.181770e+02
# max           1.474500e+02             1.474500e+02  1.474500e+02
#
#        Information Weaponization          DDoS  Data Destruction  \
# count               2.211900e+06  2.211900e+06      2.211900e+06
# mean                4.609628e+01  1.318203e+01      1.629142e+01
# std                 3.186462e+01  3.072308e+01      3.732569e+01
# min                 0.000000e+00  0.000000e+00      0.000000e+00
# 25%                 1.814000e+01  0.000000e+00      0.000000e+00
# 50%                 4.764700e+01  0.000000e+00      0.000000e+00
# 75%                 7.332900e+01  0.000000e+00      0.000000e+00
# max                 1.474500e+02  1.474500e+02      1.474500e+02
#
#        Critical Infrastructure Disruption
# count                        2.211900e+06
# mean                         1.112024e+01
# std                          2.689829e+01
# min                          0.000000e+00
# 25%                          0.000000e+00
# 50%                          0.000000e+00
# 75%                          0.000000e+00
# max                          1.474500e+02

# %%
is_fb = df[df['Organization']=='FancyBear'].index
df.drop(is_fb, inplace=True)
is_cb = df[df['Organization']=='CozyBear'].index
df.drop(is_cb, inplace=True)
is_veb = df[df['Organization']=='VenomousBear'].index
df.drop(is_veb, inplace=True)
is_vob = df[df['Organization']=='VoodooBear'].index
df.drop(is_vob, inplace=True)
is_bb = df[df['Organization']=='BerserkBear'].index
df.drop(is_bb, inplace=True)
is_pb = df[df['Organization']=='PrimitiveBear'].index
df.drop(is_pb, inplace=True)
df.describe()
# Out:
#                Step       AgentID  Spear Phishing      Zero Day  \
# count  2.190000e+06  2.190000e+06    2.190000e+06  2.190000e+06
# mean   1.825500e+03  3.065000e+02    1.023406e+02  4.958996e+01
# std    1.053664e+03  1.732049e+02    2.893374e+01  2.804958e+01
# min    1.000000e+00  7.000000e+00    4.001300e+01  1.013000e+00
# 25%    9.130000e+02  1.567500e+02    7.750700e+01  2.529500e+01
# 50%    1.825500e+03  3.065000e+02    1.025080e+02  4.958800e+01
# 75%    2.738000e+03  4.562500e+02    1.274960e+02  7.389100e+01
# max    3.650000e+03  6.060000e+02    1.511250e+02  9.834800e+01
#
#        Tool Sophistication  Attribution Obfuscation       Stealth  \
# count         2.190000e+06             2.190000e+06  2.190000e+06
# mean          8.705785e+01             9.057056e+01  9.154318e+01
# std           2.770060e+01             3.096900e+01  3.114319e+01
# min           3.001300e+01             1.501300e+01  1.501300e+01
# 25%           6.368200e+01             6.695200e+01  6.771900e+01
# 50%           8.734250e+01             9.189300e+01  9.268100e+01
# 75%           1.109270e+02             1.169100e+02  1.178400e+02
# max           1.345760e+02             1.412640e+02  1.431830e+02
#
#        Information Weaponization          DDoS  Data Destruction  \
# count               2.190000e+06  2.190000e+06      2.190000e+06
# mean                4.614480e+01  1.280352e+01      1.566279e+01
# std                 3.147417e+01  3.016125e+01      3.652600e+01
# min                 0.000000e+00  0.000000e+00      0.000000e+00
# 25%                 1.904400e+01  0.000000e+00      0.000000e+00
# 50%                 4.781800e+01  0.000000e+00      0.000000e+00
# 75%                 7.324400e+01  0.000000e+00      0.000000e+00
# max                 9.889400e+01  1.166750e+02      1.386070e+02
#
#        Critical Infrastructure Disruption
# count                        2.190000e+06
# mean                         1.066279e+01
# std                          2.600017e+01
# min                          0.000000e+00
# 25%                          0.000000e+00
# 50%                          0.000000e+00
# 75%                          0.000000e+00
# max                          1.086070e+02

# %%
agent_data={}
for rownumber, row in df.iterrows():
    if row['AgentID'] in agent_data.keys():
        agent_data[row['AgentID']]['Spear Phishing'].append(row['Spear Phishing'])
    else:
        agent_data[row['AgentID']] = {'Spear Phishing': [row['Spear Phishing']]}

for rownumber, row in df.iterrows():
    if 'Zero Day' in agent_data[row['AgentID']].keys():
        agent_data[row['AgentID']]['Zero Day'].append(row['Zero Day'])
    else: 
        agent_data[row['AgentID']]['Zero Day'] = [row['Zero Day']]

for rownumber, row in df.iterrows():
    if 'Tool Sophistication' in agent_data[row['AgentID']].keys():
        agent_data[row['AgentID']]['Tool Sophistication'].append(row['Tool Sophistication'])
    else: 
        agent_data[row['AgentID']]['Tool Sophistication'] = [row['Tool Sophistication']]

for rownumber, row in df.iterrows():
    if 'Attribution Obfuscation' in agent_data[row['AgentID']].keys():
        agent_data[row['AgentID']]['Attribution Obfuscation'].append(row['Attribution Obfuscation'])
    else: 
        agent_data[row['AgentID']]['Attribution Obfuscation'] = [row['Attribution Obfuscation']]
        
for rownumber, row in df.iterrows():
    if 'Stealth' in agent_data[row['AgentID']].keys():
        agent_data[row['AgentID']]['Stealth'].append(row['Stealth'])
    else: 
        agent_data[row['AgentID']]['Stealth'] = [row['Stealth']]

for rownumber, row in df.iterrows():
    if 'Information Weaponization' in agent_data[row['AgentID']].keys():
        agent_data[row['AgentID']]['Information Weaponization'].append(row['Information Weaponization'])
    else: 
        agent_data[row['AgentID']]['Information Weaponization'] = [row['Information Weaponization']]

for rownumber, row in df.iterrows():
    if 'DDoS' in agent_data[row['AgentID']].keys():
        agent_data[row['AgentID']]['DDoS'].append(row['DDoS'])
    else: 
        agent_data[row['AgentID']]['DDoS'] = [row['DDoS']]

for rownumber, row in df.iterrows():
    if 'Data Destruction' in agent_data[row['AgentID']].keys():
        agent_data[row['AgentID']]['Data Destruction'].append(row['Data Destruction'])
    else: 
        agent_data[row['AgentID']]['Data Destruction'] = [row['Data Destruction']]
        
for rownumber, row in df.iterrows():
    if 'Critical Infrastructure Disruption' in agent_data[row['AgentID']].keys():
        agent_data[row['AgentID']]['Critical Infrastructure Disruption'].append(row['Critical Infrastructure Disruption'])
    else: 
        agent_data[row['AgentID']]['Critical Infrastructure Disruption'] = [row['Critical Infrastructure Disruption']]

# %%
def plot_average(agent_data, attribute):
    attribute_average = []
    for x in range(3650):
        step = []
        agent_interested = set()
        for k, v in agent_data.items():
            if v[attribute][x] == 0:
                pass
            else:
                step.append(v[attribute][x])
                agent_interested.add(k)
        avg = sum(step)/len(agent_interested)
        attribute_average.append(avg)
    return attribute_average

# %%
listoflists = {}
attributes = list(agent_data[7].keys())
for a in attributes:
    listoflists[a] = plot_average(agent_data, a)

# %%
Step = list(range(1,3651))
fig, ax = plt.subplots(figsize=(20, 15))
for k, v in listoflists.items():
    ax.scatter(Step, v, label=k)
ax.legend()
ax.set_ylabel('Traits')
ax.set_xlabel('Step')
plt.title('Iranian Agent Average')
# Out:
# Text(0.5, 1.0, 'Iranian Agent Average')

# %%
Step = list(df['Step'])
Traits = []
skip = ['Step', 'AgentID', 'Organization']
labels = []
for a in df:
    if a in skip:
        pass        
    else:
        Traits.append([list(df[a]), a])
fig, ax = plt.subplots(figsize=(20, 15))
for t in Traits:
    ax.scatter(Step, t[0], label=t[1])
ax.legend()
ax.set_ylabel('Traits')
ax.set_xlabel('Step')
plt.title('Iranian Agents')
# Out:
# Text(0.5, 1.0, 'Iranian Agents')

# %%
is_rfk = df['Organization']=='RefinedKitten'
RefinedKitten = df[is_rfk]
RefinedKitten.describe()
# Out:
#                 Step       AgentID  Spear Phishing       Zero Day  \
# count  365000.000000  365000.00000   365000.000000  365000.000000
# mean     1825.500000      56.50000      101.330980      49.606901
# std      1053.665645      28.86611       30.561386      28.049918
# min         1.000000       7.00000       40.013000       1.013000
# 25%       913.000000      31.75000       77.552000      25.309750
# 50%      1825.500000      56.50000      102.558000      49.602000
# 75%      2738.000000      81.25000      127.546250      73.906000
# max      3650.000000     106.00000      151.111000      98.348000
#
#        Tool Sophistication  Attribution Obfuscation        Stealth  \
# count        365000.000000            365000.000000  365000.000000
# mean             89.050895                96.892920      97.360615
# std              25.017063                25.568795      26.143134
# min              50.013000                50.013000      50.013000
# 25%              66.511000                75.684750      75.684750
# 50%              87.342500                97.688000      97.688000
# 75%             110.925250               118.580000     119.680000
# max             134.574000               141.264000     143.183000
#
#        Information Weaponization           DDoS  Data Destruction  \
# count              365000.000000  365000.000000     365000.000000
# mean                   52.753798      76.821129         93.976734
# std                    28.430934      23.244385         25.400817
# min                     1.013000      35.013000         50.013000
# 25%                    28.056000      56.959750         71.959750
# 50%                    55.064000      77.546500         93.956000
# 75%                    77.508000      96.830250        115.958000
# max                    98.894000     116.675000        138.607000
#
#        Critical Infrastructure Disruption
# count                       365000.000000
# mean                            63.976734
# std                             25.400817
# min                             20.013000
# 25%                             41.959750
# 50%                             63.956000
# 75%                             85.958000
# max                            108.607000

# %%
Step = list(RefinedKitten['Step'])
Traits = []
skip = ['Step', 'AgentID', 'Organization']
labels = []
for a in RefinedKitten:
    if a in skip:
        pass        
    else:
        Traits.append([list(RefinedKitten[a]), a])
fig, ax = plt.subplots(figsize=(20, 15))
for t in Traits:
    ax.scatter(Step, t[0], label=t[1])
ax.legend()
ax.set_ylabel('Traits')
ax.set_xlabel('Step')
plt.title('Refined Kitten Agents')
# Out:
# Text(0.5, 1.0, 'Refined Kitten Agents')

# %%
is_ik = df['Organization']=='ImperialKitten'
ImperialKitten = df[is_ik]
ImperialKitten.describe()
# Out:
#                 Step       AgentID  Spear Phishing       Zero Day  \
# count  365000.000000  365000.00000   365000.000000  365000.000000
# mean     1825.500000     156.50000      102.084030      49.582727
# std      1053.665645      28.86611       29.235176      28.049445
# min         1.000000     107.00000       50.013000       1.013000
# 25%       913.000000     131.75000       77.497000      25.290000
# 50%      1825.500000     156.50000      102.494000      49.579500
# 75%      2738.000000     181.25000      127.489000      73.888000
# max      3650.000000     206.00000      151.112000      98.212000
#
#        Tool Sophistication  Attribution Obfuscation        Stealth  \
# count        365000.000000            365000.000000  365000.000000
# mean             85.968310                83.373539      83.761824
# std              29.214331                36.095196      36.576297
# min              30.013000                20.013000      20.013000
# 25%              62.791000                51.531750      51.531750
# 50%              87.340500                84.490000      84.490000
# 75%             110.927000               116.464250     117.405000
# max             134.553000               141.147000     143.020000
#
#        Information Weaponization      DDoS  Data Destruction  \
# count              365000.000000  365000.0          365000.0
# mean                   57.875710       0.0               0.0
# std                    22.719616       0.0               0.0
# min                    20.013000       0.0               0.0
# 25%                    38.272000       0.0               0.0
# 50%                    56.475000       0.0               0.0
# 75%                    77.504000       0.0               0.0
# max                    98.858000       0.0               0.0
#
#        Critical Infrastructure Disruption
# count                            365000.0
# mean                                  0.0
# std                                   0.0
# min                                   0.0
# 25%                                   0.0
# 50%                                   0.0
# 75%                                   0.0
# max                                   0.0

# %%
Step = list(ImperialKitten['Step'])
Traits = []
skip = ['Step', 'AgentID', 'Organization', 'Critical Infrastructure Disruption', 'Data Destruction', 'DDoS']
labels = []
for a in ImperialKitten:
    if a in skip:
        pass        
    else:
        Traits.append([list(ImperialKitten[a]), a])
fig, ax = plt.subplots(figsize=(20, 15))
for t in Traits:
    ax.scatter(Step, t[0], label=t[1])
ax.legend()
ax.set_ylabel('Traits')
ax.set_xlabel('Step')
plt.title('Imperial Kitten Agents')
# Out:
# Text(0.5, 1.0, 'Imperial Kitten Agents')

# %%
is_ck = df['Organization']=='CharmingKitten'
CharmingKitten = df[is_ck]
CharmingKitten.describe()
# Out:
#                 Step       AgentID  Spear Phishing       Zero Day  \
# count  365000.000000  365000.00000   365000.000000  365000.000000
# mean     1825.500000     256.50000      102.086650      49.584909
# std      1053.665645      28.86611       29.234623      28.049420
# min         1.000000     207.00000       50.013000       1.013000
# 25%       913.000000     231.75000       77.501000      25.295750
# 50%      1825.500000     256.50000      102.496500      49.582500
# 75%      2738.000000     281.25000      127.481000      73.882000
# max      3650.000000     306.00000      151.113000      98.201000
#
#        Tool Sophistication  Attribution Obfuscation        Stealth  \
# count        365000.000000            365000.000000  365000.000000
# mean             85.970918                82.601388      82.990691
# std              29.213716                37.186404      37.662191
# min              30.013000                15.013000      15.013000
# 25%              62.793000                50.550000      50.550000
# 50%              87.341000                84.493000      84.493000
# 75%             110.920000               116.455000     117.394000
# max             134.559000               141.146000     143.002000
#
#        Information Weaponization      DDoS  Data Destruction  \
# count              365000.000000  365000.0          365000.0
# mean                   60.785815       0.0               0.0
# std                    19.723548       0.0               0.0
# min                    30.013000       0.0               0.0
# 25%                    43.969000       0.0               0.0
# 50%                    57.926000       0.0               0.0
# 75%                    77.497000       0.0               0.0
# max                    98.838000       0.0               0.0
#
#        Critical Infrastructure Disruption
# count                            365000.0
# mean                                  0.0
# std                                   0.0
# min                                   0.0
# 25%                                   0.0
# 50%                                   0.0
# 75%                                   0.0
# max                                   0.0

# %%
Step = list(CharmingKitten['Step'])
Traits = []
skip = ['Step', 'AgentID', 'Organization', 'Critical Infrastructure Disruption', 'Data Destruction', 'DDoS']
labels = []
for a in CharmingKitten:
    if a in skip:
        pass        
    else:
        Traits.append([list(CharmingKitten[a]), a])
fig, ax = plt.subplots(figsize=(20, 15))
for t in Traits:
    ax.scatter(Step, t[0], label=t[1])
ax.legend()
ax.set_ylabel('Traits')
ax.set_xlabel('Step')
plt.title('Charming Kitten Agents')
# Out:
# Text(0.5, 1.0, 'Charming Kitten Agents')

# %%
is_hk = df['Organization']=='HelixKitten'
HelixKitten = df[is_hk]
HelixKitten.describe()
# Out:
#                 Step       AgentID  Spear Phishing       Zero Day  \
# count  365000.000000  365000.00000   365000.000000  365000.000000
# mean     1825.500000     356.50000      103.220651      49.584076
# std      1053.665645      28.86611       27.589186      28.049607
# min         1.000000     307.00000       60.013000       1.013000
# 25%       913.000000     331.75000       77.492750      25.287000
# 50%      1825.500000     356.50000      102.499000      49.584500
# 75%      2738.000000     381.25000      127.484250      73.885000
# max      3650.000000     406.00000      151.123000      98.203000
#
#        Tool Sophistication  Attribution Obfuscation        Stealth  \
# count        365000.000000            365000.000000  365000.000000
# mean             87.113219                88.562022      92.325271
# std              27.478190                31.030153      29.637516
# min              40.013000                35.013000      40.013000
# 25%              62.783500                61.643000      66.643000
# 50%              87.346000                88.207000      93.207000
# 75%             110.925000               116.458000     117.398000
# max             134.538000               141.114000     143.020000
#
#        Information Weaponization      DDoS  Data Destruction  \
# count              365000.000000  365000.0          365000.0
# mean                   52.725051       0.0               0.0
# std                    28.447999       0.0               0.0
# min                     1.013000       0.0               0.0
# 25%                    27.998750       0.0               0.0
# 50%                    55.023000       0.0               0.0
# 75%                    77.504000       0.0               0.0
# max                    98.846000       0.0               0.0
#
#        Critical Infrastructure Disruption
# count                            365000.0
# mean                                  0.0
# std                                   0.0
# min                                   0.0
# 25%                                   0.0
# 50%                                   0.0
# 75%                                   0.0
# max                                   0.0

# %%
Step = list(HelixKitten['Step'])
Traits = []
skip = ['Step', 'AgentID', 'Organization', 'Critical Infrastructure Disruption', 'Data Destruction', 'DDoS']
labels = []
for a in HelixKitten:
    if a in skip:
        pass        
    else:
        Traits.append([list(HelixKitten[a]), a])
fig, ax = plt.subplots(figsize=(20, 15))
for t in Traits:
    ax.scatter(Step, t[0], label=t[1])
ax.legend()
ax.set_ylabel('Traits')
ax.set_xlabel('Step')
plt.title('Helix Kitten Agents')
# Out:
# Text(0.5, 1.0, 'Helix Kitten Agents')

# %%
is_sk = df['Organization']=='StaticKitten'
StaticKitten = df[is_sk]
StaticKitten.describe()
# Out:
#                 Step       AgentID  Spear Phishing       Zero Day  \
# count  365000.000000  365000.00000   365000.000000  365000.000000
# mean     1825.500000     456.50000      102.091163      49.589414
# std      1053.665645      28.86611       29.234767      28.049594
# min         1.000000     407.00000       50.013000       1.013000
# 25%       913.000000     431.75000       77.500750      25.295750
# 50%      1825.500000     456.50000      102.502000      49.585000
# 75%      2738.000000     481.25000      127.489250      73.890000
# max      3650.000000     506.00000      151.125000      98.231000
#
#        Tool Sophistication  Attribution Obfuscation        Stealth  \
# count        365000.000000            365000.000000  365000.000000
# mean             87.120537                96.804141      97.217796
# std              27.475443                23.748696      24.274159
# min              40.013000                60.013000      60.013000
# 25%              62.792000                75.281000      75.281000
# 50%              87.345000                95.238000      95.238000
# 75%             110.929000               116.463250     117.405000
# max             134.576000               141.139000     143.035000
#
#        Information Weaponization      DDoS  Data Destruction  \
# count                   365000.0  365000.0          365000.0
# mean                         0.0       0.0               0.0
# std                          0.0       0.0               0.0
# min                          0.0       0.0               0.0
# 25%                          0.0       0.0               0.0
# 50%                          0.0       0.0               0.0
# 75%                          0.0       0.0               0.0
# max                          0.0       0.0               0.0
#
#        Critical Infrastructure Disruption
# count                            365000.0
# mean                                  0.0
# std                                   0.0
# min                                   0.0
# 25%                                   0.0
# 50%                                   0.0
# 75%                                   0.0
# max                                   0.0

# %%
Step = list(StaticKitten['Step'])
Traits = []
skip = ['Step', 'AgentID', 'Organization', 'Critical Infrastructure Disruption', 'Data Destruction', 'DDoS', 'Information Weaponization']
labels = []
for a in StaticKitten:
    if a in skip:
        pass        
    else:
        Traits.append([list(StaticKitten[a]), a])
fig, ax = plt.subplots(figsize=(20, 15))
for t in Traits:
    ax.scatter(Step, t[0], label=t[1])
ax.legend()
ax.set_ylabel('Traits')
ax.set_xlabel('Step')
plt.title('Static Kitten Agents')
# Out:
# Text(0.5, 1.0, 'Static Kitten Agents')

# %%
is_rmk = df['Organization']=='RemixKitten'
RemixKitten = df[is_rmk]
RemixKitten.describe()
# Out:
#                 Step       AgentID  Spear Phishing       Zero Day  \
# count  365000.000000  365000.00000   365000.000000  365000.000000
# mean     1825.500000     556.50000      103.230270      49.591757
# std      1053.665645      28.86611       27.586375      28.049665
# min         1.000000     507.00000       60.013000       1.013000
# 25%       913.000000     531.75000       77.500750      25.293000
# 50%      1825.500000     556.50000      102.502000      49.588000
# 75%      2738.000000     581.25000      127.492000      73.892250
# max      3650.000000     606.00000      151.125000      98.213000
#
#        Tool Sophistication  Attribution Obfuscation        Stealth  \
# count        365000.000000            365000.000000  365000.000000
# mean             87.123213                95.189351      95.602878
# std              27.475001                25.858415      26.367102
# min              40.013000                50.013000      50.013000
# 25%              62.793000                73.115750      73.115750
# 50%              87.346000                95.246000      95.246000
# 75%             110.932000               116.468250     117.410250
# max             134.546000               141.164000     143.036000
#
#        Information Weaponization      DDoS  Data Destruction  \
# count              365000.000000  365000.0          365000.0
# mean                   52.728448       0.0               0.0
# std                    28.448203       0.0               0.0
# min                     1.013000       0.0               0.0
# 25%                    28.006000       0.0               0.0
# 50%                    55.037000       0.0               0.0
# 75%                    77.508000       0.0               0.0
# max                    98.853000       0.0               0.0
#
#        Critical Infrastructure Disruption
# count                            365000.0
# mean                                  0.0
# std                                   0.0
# min                                   0.0
# 25%                                   0.0
# 50%                                   0.0
# 75%                                   0.0
# max                                   0.0

# %%
Step = list(RemixKitten['Step'])
Traits = []
skip = ['Step', 'AgentID', 'Organization', 'Critical Infrastructure Disruption', 'Data Destruction', 'DDoS']
labels = []
for a in RemixKitten:
    if a in skip:
        pass        
    else:
        Traits.append([list(RemixKitten[a]), a])
fig, ax = plt.subplots(figsize=(20, 15))
for t in Traits:
    ax.scatter(Step, t[0], label=t[1])
ax.legend()
ax.set_ylabel('Traits')
ax.set_xlabel('Step')
plt.title('Remix Kitten Agents')
# Out:
# Text(0.5, 1.0, 'Remix Kitten Agents')
